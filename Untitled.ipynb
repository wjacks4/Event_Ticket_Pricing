# %%
import json
from dateutil import parser
import time
import os
import subprocess
import urllib
import urllib.request
import pandas as pd
import unidecode
from unidecode import unidecode
import requests
import urllib
from urllib import parse
import sys
import base64
import numpy as np
#import mysql-python
import pymysql
#import MySQLdb
import base64
import datetime
from datetime import datetime
import easydict 
from collections import defaultdict
import pickle
import pprint
from pprint import pprint


import urllib
import pandas as pd
import numpy as np
import json
import requests

import boto3

# %%
base_url = ('https://api.seatgeek.com/2/')

client_id_str = ('MTM4MTIyMDZ8MTU1NDQ3MTkxMy43Ng')

client_secret_str = ('c49766eaad2bc8bc33810d112d141ca9a09b0a78b1be52c459eb19c5fd3527a5')

# %%
dynamodb = boto3.resource('dynamodb')
dynamoTable = dynamodb.Table('Event_Table')

# %%
def Data_Fetch_pymysql():

    #Fetch_QL = 'SELECT * FROM ARTISTS_ONLY;'
    
    #USING pymysql#
    connection = pymysql.connect (host = 'ticketsdb.cxrz9l1i58ux.us-west-2.rds.amazonaws.com',
                                  user = 'tickets_user',
                                  password = 'tickets_pass',
                                  db = 'tickets_db')
    
    Fetch_QL = 'SELECT * FROM Artists_expanded;'
    cursor = connection.cursor()
    Artists_DF = pd.read_sql('SELECT * FROM ARTISTS_WITH_EVENTS order by current_followers desc', con = connection)  
    return Artists_DF

Data_Fetch_pymysql()
# Out:
#                   artist  popularity  current_followers  \
# 0            Amon Amarth          67             491400
# 1          Alec Benjamin          83             487418
# 2                   Cuco          73             486991
# 3    Motionless In White          64             486892
# 4           Old Dominion          74             484724
# 5        Kacey Musgraves          78             484580
# 6         Eli Young Band          68             484072
# 7              Matisyahu          64             482911
# 8             Rebelution          70             479276
# 9              Buddy Guy          57             477163
# 10                 dodie          68             474856
# 11              Blueface          83             467157
# 12    for KING & COUNTRY          68             462775
# 13                 Tycho          64             460985
# 14            Dean Lewis          83             459267
# 15        The Raconteurs          65             458130
# 16       Smokey Robinson          66             455039
# 17         Joe Bonamassa          62             451225
# 18                Atreyu          65             450584
# 19              GoldLink          73             446802
# 20       Scotty McCreery          68             444641
# 21      Brothers Osborne          70             443428
# 22            Switchfoot          65             440919
# 23              Hot Chip          65             437201
# 24                Clairo          75             436318
# 25      Memphis May Fire          60             425768
# 26                  Tank          63             425609
# 27             Cash Cash          73             424653
# 28           Dirty Heads          70             418669
# 29           Josh Groban          66             417706
# ..                   ...         ...                ...
# 165             Baroness          54             142657
# 166        Morgan Wallen          73             141427
# 167             Jai Wolf          67             139378
# 168          Steve Earle          60             137216
# 169              SLANDER          66             136372
# 170   Japanese Breakfast          57             136164
# 171           Jonny Lang          50             135725
# 172         Jim Gaffigan          59             134589
# 173             Keb' Mo'          56             133182
# 174       Chelsea Cutler          74             132437
# 175     Blackberry Smoke          57             132137
# 176         Ryan Bingham          58             129489
# 177         Chris Janson          63             128702
# 178         Tauren Wells          64             128041
# 179                  SiR          64             126873
# 180       Frankie Cosmos          58             126691
# 181   Family of the Year          57             125906
# 182              Whitney          61             125114
# 183        Ziggy Alberts          67             124448
# 184               Jinjer          56             124244
# 185         Aaron Watson          61             122879
# 186             SG Lewis          68             122525
# 187        Todd Rundgren          56             122117
# 188             Calexico          54             121969
# 189       Fit For A King          59             121783
# 190                SALES          63             121211
# 191          Still Woozy          70             120136
# 192             Wage War          61             120056
# 193     After The Burial          59             118874
# 194                11:11          55             116947
#
#                   artist_id
# 0    3pulcT2wt7FEG10lQlqDJL
# 1    5IH6FPUwQTxPSXurCrcIov
# 2    2Tglaf8nvDzwSQnpSrjLHP
# 3    6MwPCCR936cYfM1dLsGVnl
# 4    6y8XlgIV8BLlIg1tT1R10i
# 5    70kkdajctXSbqSMJbQO424
# 6    6eKWqnckwdIlSnjaYgIyxv
# 7    5eyMzR1hYiEZtN2c9ly2kw
# 8    2WjvvwAX0mdWwq3aFuUdtc
# 9    2gCsNOpiBaMNh20jQ5prf0
# 10   21TinSsF5ytwsfdyz5VSVS
# 11   3Fl1V19tmjt57oBdxXKAjJ
# 12   3sDbKMebVH2VYcRSl7u1VC
# 13   5oOhM2DFWab8XhSdQiITry
# 14   3QSQFmccmX81fWCUSPTS7y
# 15   4wo1267SJuUfHgasdlfNfc
# 16   0h9smro0z3HqUbD94jotU8
# 17   2SNzxY1OsSCHBLVi77mpPQ
# 18   3LkSiHbjqOHCKCqBfEZOTv
# 19   5XenQ7XfcvQdfIbpLEFaKQ
# 20   6ZV6lGY0prbqpTD0Md8i29
# 21   39NR3AUhpbbqKM33vWn2fp
# 22   6S58b0fr8TkWrEHOH4tRVu
# 23   37uLId6Z5ZXCx19vuruvv5
# 24   3l0CmX0FuQjFxr8SK7Vqag
# 25   7cNNNhdJDrt3vgQjwSavNf
# 26   4mwXUEKaW4ftbncf9Hi58l
# 27   1LOB7jTeEV14pHai6EXSzF
# 28   6GkJh85o22LfD2vgL9DP6f
# 29   6cXMpsP9x0SH4kFfMyVezF
# ..                      ...
# 165  3KdXhEwbqFHfNfSk7L9E87
# 166  4oUHIQIBe0LHzYfvXNW4QM
# 167  24V5UY0nChKpnb1TBPJhCw
# 168  2UBTfUoLI07iRqGeUrwhZh
# 169  20DZAfCuP1TKZl5KcY7z3Q
# 170  7MoIc5s9KXolCBH1fy9kkw
# 171  5rX1EodZfwxmW4fQX2Caot
# 172  0f4zEF6vddRYg7Y3GDL8lk
# 173  6iDaoPZVgxrTkndDCisX8F
# 174  5JMLG56F1X5mFmWNmS0iAp
# 175  5P1oS9DUTPEqcrmXDmX4p8
# 176  31z9f9AyPawiq0qlBO1M3i
# 177  60gmlHZmT16wiO9GiXKYK9
# 178  3SKza3YPBri1k43LB1Tqy4
# 179  3QTDHixorJelOLxoxcjqGx
# 180  0x4xCoWaOFd3WsKarzaxnW
# 181  7zsin6IgVsR1rqSRCNYDwq
# 182  32aUoW94mJ7xTJI7fG0V1G
# 183  6tuPdaFPIytg3l2f51L7Hw
# 184  7o6cOczXTB8ioTAAJTbESf
# 185  5BKzvAPtNXnt0LwzGvKOH3
# 186  0GG2cWaonE4JPrjcCCQ1EG
# 187  0Lpr5wXzWLtDWm1SjNbpPb
# 188  1OmdWpAh1pucAuZPzJaxIJ
# 189  0OgdRTPItr9dw4XYp4JJUx
# 190  6vVztIuqdDHvYWxOEXCzjN
# 191  4iMO20EPodreIaEl8qW66y
# 192  6bu7CtcOMWcS0BMq7snHW6
# 193  0uNj4RxFjG0iVPlZS753en
# 194  5gsyao2Qm21EKylbVIuRQ3
#
# [195 rows x 4 columns]

# %%
events_dict = dict()

# %%
def dynamo():
    
    #with open('C:/Users/wjack/Documents/test.pickle', 'rb') as handle:
    with open('C:/Users/bswxj01/Documents/test.pickle', 'rb') as handle:
        events_dict = pickle.load(handle)
    
    #event = events_dict['AtreyuDowntown Las Vegas Events CenterLas VegasNV2019-10-18T10:30:00']
    
    #json_test = json.loads(event)
    
    #print(json_test[0])
    
    
    #print(events_dict)
    #test = events_dict['RebelutionThe Met PhiladelphiaPhiladelphiaPA2019-07-31T23:00:00']
    #print(test)
    
    dynamoTable = dynamodb.Table('Event_Table')
    
    for event in events_dict:
    
        event_dat = json.loads(events_dict[event])[0]
        pprint(event_dat)

        artist = event_dat['artist']
        city = event_dat['city']
        date_UTC = event_dat['date_UTC']
        name = event_dat['name']
        state = event_dat['state']
        venue = event_dat['venue']

        create_ts = event_dat['create_ts']
        highest_price = event_dat['highest_price']
        listing_count = event_dat['listing_count']
        lowest_price = event_dat['lowest_price']
        med_price = event_dat['med_price']
        
        event_dat = {'artist':artist, 'city':city, 'date_UTC':date_UTC, 'name':name, 'state':state, 'venue':venue}
        price_data = [{'create_ts': create_ts, 'highest_price':highest_price}]
        price_data2 = [{'create_ts': create_ts, 'highest_price':highest_price}]


        #dynamoTable.put_item(
        #    Item={
        #        'Event_ID':event,
        #        'Event_name':name,
        #        'Event_data':event_dat,
        #        'Ticket_prices':price_data
        #    }
        #)
        
        
        dynamoTable.update_item(

            Key = {
                'Event_ID':event
            },
            UpdateExpression="SET Ticket_prices = list_append(Ticket_prices, :i)",
            ExpressionAttributeValues={
                    ':i': price_data2
            }

        )
        
dynamo()
# Out:
# {'Event_ID': 'TEST',
#  'ID': 4942018,
#  'artist': 'Cuco',
#  'artist_id': '2Tglaf8nvDzwSQnpSrjLHP',
#  'avg_price': 222,
#  'city': 'Salt Lake City',
#  'create_ts': 1564674934328,
#  'date_UTC': '2019-09-19T01:00:00',
#  'highest_price': 1185,
#  'listing_count': 22,
#  'lowest_price': 53,
#  'med_price': 79,
#  'name': 'Cuco',
#  'state': 'UT',
#  'venue': 'The Complex'}
# {'Event_ID': 'TEST',
#  'ID': 4667266,
#  'artist': 'Matisyahu',
#  'artist_id': '5eyMzR1hYiEZtN2c9ly2kw',
#  'avg_price': 203,
#  'city': 'Thornville',
#  'create_ts': 1564674934328,
#  'date_UTC': '2019-08-01T16:00:00',
#  'highest_price': 203,
#  'listing_count': 1,
#  'lowest_price': 203,
#  'med_price': 203,
#  'name': 'The werk out music and arts festival with The Werks, Lettuce, '
#          'Spafford',
#  'state': 'OH',
#  'venue': 'Legend Valley'}
# {'Event_ID': 'TEST',
#  'ID': 4745382,
#  'artist': 'Rebelution',
#  'artist_id': '2WjvvwAX0mdWwq3aFuUdtc',
#  'avg_price': 100,
#  'city': 'Boston',
#  'create_ts': 1564674934328,
#  'date_UTC': '2019-08-01T23:00:00',
#  'highest_price': 100,
#  'listing_count': 1,
#  'lowest_price': 100,
#  'med_price': 100,
#  'name': 'Rebelution with Collie Buddz and Protoje',
#  'state': 'MA',
#  'venue': 'Rockland Trust Bank Pavilion'}
# {'Event_ID': 'TEST',
#  'ID': 4702130,
#  'artist': 'dodie',
#  'artist_id': '21TinSsF5ytwsfdyz5VSVS',
#  'avg_price': 64,
#  'city': 'Washington',
#  'create_ts': 1564674934328,
#  'date_UTC': '2019-09-05T23:00:00',
#  'highest_price': 1129,
#  'listing_count': 38,
#  'lowest_price': 18,
#  'med_price': 25,
#  'name': 'Dodie Clark with dodie',
#  'state': 'DC',
#  'venue': '9:30 Club'}
# {'Event_ID': 'TEST',
#  'ID': 4917061,
#  'artist': 'Blueface',
#  'artist_id': '3Fl1V19tmjt57oBdxXKAjJ',
#  'avg_price': None,
#  'city': 'Cincinnati',
#  'create_ts': 1564674934328,
#  'date_UTC': '2019-08-02T23:00:00',
#  'highest_price': None,
#  'listing_count': None,
#  'lowest_price': None,
#  'med_price': None,
#  'name': 'Blueface with NLE Choppa',
#  'state': 'OH',
#  'venue': 'Bogarts'}
# {'Event_ID': 'TEST',
#  'ID': 4866091,
#  'artist': 'Tycho',
#  'artist_id': '5oOhM2DFWab8XhSdQiITry',
#  'avg_price': 163,
#  'city': 'Los Angeles',
#  'create_ts': 1564674934328,
#  'date_UTC': '2019-09-06T03:00:00',
#  'highest_price': 673,
#  'listing_count': 85,
#  'lowest_price': 64,
#  'med_price': 134,
#  'name': 'Tycho with Chrome Sparks',
#  'state': 'CA',
#  'venue': 'The Greek Theatre'}
# {'Event_ID': 'TEST',
#  'ID': 4891340,
#  'artist': 'Atreyu',
#  'artist_id': '3LkSiHbjqOHCKCqBfEZOTv',
#  'avg_price': 256,
#  'city': 'Las Vegas',
#  'create_ts': 1564674934328,
#  'date_UTC': '2019-10-18T10:30:00',
#  'highest_price': 256,
#  'listing_count': 1,
#  'lowest_price': 256,
#  'med_price': 256,
#  'name': 'Las Rageous (2 Day Pass) with Bring Me The Horizon, Rob Zombie, The '
#          'Used, and more',
#  'state': 'NV',
#  'venue': 'Downtown Las Vegas Events Center'}
# {'Event_ID': 'TEST',
#  'ID': 4941743,
#  'artist': 'GoldLink',
#  'artist_id': '5XenQ7XfcvQdfIbpLEFaKQ',
#  'avg_price': None,
#  'city': 'Taos',
#  'create_ts': 1564674934328,
#  'date_UTC': '2019-08-16T20:00:00',
#  'highest_price': None,
#  'listing_count': None,
#  'lowest_price': None,
#  'med_price': None,
#  'name': 'Justin Jay: Justin Martin with George Clinton and Too Many Zooz and '
#          'Mija and Goldlink',
#  'state': 'NM',
#  'venue': 'Kit Carson Park'}

# %%
def SeatGeek_Events():
    
    Artists_df = Data_Fetch_pymysql().head(20)
    #Artists_df = Data_Fetch_pymysql().head(200)

    #------------------GET ARTIST LIST FROM DF----------------#
    artists = Artists_df['artist']

    #-----------GET CURRENT DATETIME FOR TIMESTAMP ADD------------#
    current_Date = datetime.now()

    i = 1

    #---------------BEGIN BUILDING EVENTS DATAFRAME FROM JSON----------------#
    #-----CREATE BLANK DATAFRAME FOR APPENDING, ISOLATE EVENTS FROM JSON-----#
    event_df = pd.DataFrame()

    #--------------------LOOP THRU ARTISTS--------------------#
    #for artist in artists:	
    for artist_dat in Artists_df.iterrows():

        #-----------EXTRACT ARTIST FROM THE ROW------------------#
        spotify_artist = artist_dat[1]['artist']
        spotify_artist_id = artist_dat[1]['artist_id']

        performer_slug=spotify_artist

        try:

            url = 'https://api.seatgeek.com/2/events?format=json'
            payload = {'per_page' : 1,
                       'performers.slug':performer_slug,
                       'client_id':  client_id_str,
                      }
            r = requests.get(url, params=payload,verify=True)

            print(r.url)

            json_obj = json.loads(r.text)

            #print(json_obj)

            try:
                event_name = json_obj['events'][0]['title']
                #print(event_name)
            except KeyError as noName:
                event_name = ''

            try:
                event_id = json_obj['events'][0]['id']
                #print(event_id)
            except KeyError as noID:
                event_id = ''

            try:
                event_date_UTC = json_obj['events'][0]['datetime_utc']
                #print(event_date_utc)
            except KeyError as noDatetime:
                event_date_UTC = ''	

            try:
                event_venue = json_obj['events'][0]['venue']['name']
                #print(event_venue)
            except KeyError as noVenue:
                event_venue = ''		

            try:
                event_city = json_obj['events'][0]['venue']['city']
                #print(event_city)
            except KeyError as noCity:
                event_city = ''		


            try:
                event_state = json_obj['events'][0]['venue']['state']
                #print(event_state)
            except KeyError as noState:
                event_state = ''

            event_stats=json_obj['events'][0]['stats']
            #print(event_stats)

            try:
                avg_price = json_obj['events'][0]['stats']['average_price']
                #print(avg_price)
            except KeyError as noAvg:
                avg_price = ''

            try:
                med_price = json_obj['events'][0]['stats']['median_price']
                #print(med_price)
            except KeyError as noMed:
                med_price = ''

            try:
                lowest_price = json_obj['events'][0]['stats']['lowest_price']
                #print(lowest_price)
            except KeyError as noLowest:
                lowest_price = ''

            try:
                highest_price = json_obj['events'][0]['stats']['highest_price']
                #print(highest_price)
            except KeyError as noHighest:
                highest_price = ''	

            try:
                no_listings = json_obj['events'][0]['stats']['listing_count']
                #print(no_listings)
            except KeyError as noListingCount:
                no_listings = ''	


            event_key = spotify_artist + event_venue + event_city + event_state + event_date_UTC

            event_array = pd.DataFrame([['TEST', spotify_artist, spotify_artist_id, event_name, event_id, event_venue, event_city, event_state, event_date_UTC, lowest_price, highest_price, avg_price, med_price, no_listings, current_Date]], 
                                       columns =['Event_ID', 'artist', 'artist_id', 'name', 'ID', 'venue', 'city', 'state', 'date_UTC', 'lowest_price', 'highest_price', 'avg_price', 'med_price', 'listing_count', 'create_ts'])

            event_json = event_array.to_json(orient = 'records')

            list2 = (spotify_artist, spotify_artist_id, current_Date)

            if event_key in events_dict:

                prev_event_list = events_dict[event_key]
                appended_list = prev_event_list.append(event_json)
                events_dict[event_key]=appended_list

                #-------------THE PANDAS WAY TO DO IT----------------#
                #prev_event_df = events_dict[event_key]
                #appended_df = prev_event_df.append(event_array)
                #events_dict[event_key] = appended_df

            else:

                events_dict[event_key] = event_json

                #-----------THE PANDAS WAY TO DO IT------------#
                #vents_dict[event_key] = event_array

            print(events_dict)

            #-------APPEND EACH EVENT TO MASTER DATAFRAME...NOT SURE IF I STILL NEED THIS------#
            event_df = event_df.append(event_array)


        except IndexError as e:
            print('NO RELATED SEATGEEK EVENTS')

    print(event_df)

    #HOME LAPTOP VERSION#
    #with open('C:/Users/wjack/Documents/test.pickle', 'wb') as handle:

    #WORK LAPTOP VERSION#
    with open('C:/Users/bswxj01/Documents/test.pickle', 'wb') as handle:
        pickle.dump(events_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)


SeatGeek_Events()
# Out:
# https://api.seatgeek.com/2/events?format=json&per_page=1&performers.slug=Amon+Amarth&client_id=MTM4MTIyMDZ8MTU1NDQ3MTkxMy43Ng
# NO RELATED SEATGEEK EVENTS
# https://api.seatgeek.com/2/events?format=json&per_page=1&performers.slug=Alec+Benjamin&client_id=MTM4MTIyMDZ8MTU1NDQ3MTkxMy43Ng
# NO RELATED SEATGEEK EVENTS
# https://api.seatgeek.com/2/events?format=json&per_page=1&performers.slug=Cuco&client_id=MTM4MTIyMDZ8MTU1NDQ3MTkxMy43Ng
# {'CucoThe ComplexSalt Lake CityUT2019-09-19T01:00:00': '[{"Event_ID":"TEST","artist":"Cuco","artist_id":"2Tglaf8nvDzwSQnpSrjLHP","name":"Cuco","ID":4942018,"venue":"The Complex","city":"Salt Lake City","state":"UT","date_UTC":"2019-09-19T01:00:00","lowest_price":53,"highest_price":1185,"avg_price":222,"med_price":79,"listing_count":22,"create_ts":1564674934328}]'}
# https://api.seatgeek.com/2/events?format=json&per_page=1&performers.slug=Motionless+In+White&client_id=MTM4MTIyMDZ8MTU1NDQ3MTkxMy43Ng
# NO RELATED SEATGEEK EVENTS
# https://api.seatgeek.com/2/events?format=json&per_page=1&performers.slug=Old+Dominion&client_id=MTM4MTIyMDZ8MTU1NDQ3MTkxMy43Ng
# NO RELATED SEATGEEK EVENTS
# https://api.seatgeek.com/2/events?format=json&per_page=1&performers.slug=Kacey+Musgraves&client_id=MTM4MTIyMDZ8MTU1NDQ3MTkxMy43Ng
# NO RELATED SEATGEEK EVENTS
# https://api.seatgeek.com/2/events?format=json&per_page=1&performers.slug=Eli+Young+Band&client_id=MTM4MTIyMDZ8MTU1NDQ3MTkxMy43Ng
# NO RELATED SEATGEEK EVENTS
# https://api.seatgeek.com/2/events?format=json&per_page=1&performers.slug=Matisyahu&client_id=MTM4MTIyMDZ8MTU1NDQ3MTkxMy43Ng
# {'CucoThe ComplexSalt Lake CityUT2019-09-19T01:00:00': '[{"Event_ID":"TEST","artist":"Cuco","artist_id":"2Tglaf8nvDzwSQnpSrjLHP","name":"Cuco","ID":4942018,"venue":"The Complex","city":"Salt Lake City","state":"UT","date_UTC":"2019-09-19T01:00:00","lowest_price":53,"highest_price":1185,"avg_price":222,"med_price":79,"listing_count":22,"create_ts":1564674934328}]', 'MatisyahuLegend ValleyThornvilleOH2019-08-01T16:00:00': '[{"Event_ID":"TEST","artist":"Matisyahu","artist_id":"5eyMzR1hYiEZtN2c9ly2kw","name":"The werk out music and arts festival with The Werks, Lettuce, Spafford","ID":4667266,"venue":"Legend Valley","city":"Thornville","state":"OH","date_UTC":"2019-08-01T16:00:00","lowest_price":203,"highest_price":203,"avg_price":203,"med_price":203,"listing_count":1,"create_ts":1564674934328}]'}
# https://api.seatgeek.com/2/events?format=json&per_page=1&performers.slug=Rebelution&client_id=MTM4MTIyMDZ8MTU1NDQ3MTkxMy43Ng
# {'CucoThe ComplexSalt Lake CityUT2019-09-19T01:00:00': '[{"Event_ID":"TEST","artist":"Cuco","artist_id":"2Tglaf8nvDzwSQnpSrjLHP","name":"Cuco","ID":4942018,"venue":"The Complex","city":"Salt Lake City","state":"UT","date_UTC":"2019-09-19T01:00:00","lowest_price":53,"highest_price":1185,"avg_price":222,"med_price":79,"listing_count":22,"create_ts":1564674934328}]', 'MatisyahuLegend ValleyThornvilleOH2019-08-01T16:00:00': '[{"Event_ID":"TEST","artist":"Matisyahu","artist_id":"5eyMzR1hYiEZtN2c9ly2kw","name":"The werk out music and arts festival with The Werks, Lettuce, Spafford","ID":4667266,"venue":"Legend Valley","city":"Thornville","state":"OH","date_UTC":"2019-08-01T16:00:00","lowest_price":203,"highest_price":203,"avg_price":203,"med_price":203,"listing_count":1,"create_ts":1564674934328}]', 'RebelutionRockland Trust Bank PavilionBostonMA2019-08-01T23:00:00': '[{"Event_ID":"TEST","artist":"Rebelution","artist_id":"2WjvvwAX0mdWwq3aFuUdtc","name":"Rebelution with Collie Buddz and Protoje","ID":4745382,"venue":"Rockland Trust Bank Pavilion","city":"Boston","state":"MA","date_UTC":"2019-08-01T23:00:00","lowest_price":100,"highest_price":100,"avg_price":100,"med_price":100,"listing_count":1,"create_ts":1564674934328}]'}
# https://api.seatgeek.com/2/events?format=json&per_page=1&performers.slug=Buddy+Guy&client_id=MTM4MTIyMDZ8MTU1NDQ3MTkxMy43Ng
# NO RELATED SEATGEEK EVENTS
# https://api.seatgeek.com/2/events?format=json&per_page=1&performers.slug=dodie&client_id=MTM4MTIyMDZ8MTU1NDQ3MTkxMy43Ng
# {'CucoThe ComplexSalt Lake CityUT2019-09-19T01:00:00': '[{"Event_ID":"TEST","artist":"Cuco","artist_id":"2Tglaf8nvDzwSQnpSrjLHP","name":"Cuco","ID":4942018,"venue":"The Complex","city":"Salt Lake City","state":"UT","date_UTC":"2019-09-19T01:00:00","lowest_price":53,"highest_price":1185,"avg_price":222,"med_price":79,"listing_count":22,"create_ts":1564674934328}]', 'MatisyahuLegend ValleyThornvilleOH2019-08-01T16:00:00': '[{"Event_ID":"TEST","artist":"Matisyahu","artist_id":"5eyMzR1hYiEZtN2c9ly2kw","name":"The werk out music and arts festival with The Werks, Lettuce, Spafford","ID":4667266,"venue":"Legend Valley","city":"Thornville","state":"OH","date_UTC":"2019-08-01T16:00:00","lowest_price":203,"highest_price":203,"avg_price":203,"med_price":203,"listing_count":1,"create_ts":1564674934328}]', 'RebelutionRockland Trust Bank PavilionBostonMA2019-08-01T23:00:00': '[{"Event_ID":"TEST","artist":"Rebelution","artist_id":"2WjvvwAX0mdWwq3aFuUdtc","name":"Rebelution with Collie Buddz and Protoje","ID":4745382,"venue":"Rockland Trust Bank Pavilion","city":"Boston","state":"MA","date_UTC":"2019-08-01T23:00:00","lowest_price":100,"highest_price":100,"avg_price":100,"med_price":100,"listing_count":1,"create_ts":1564674934328}]', 'dodie9:30 ClubWashingtonDC2019-09-05T23:00:00': '[{"Event_ID":"TEST","artist":"dodie","artist_id":"21TinSsF5ytwsfdyz5VSVS","name":"Dodie Clark with dodie","ID":4702130,"venue":"9:30 Club","city":"Washington","state":"DC","date_UTC":"2019-09-05T23:00:00","lowest_price":18,"highest_price":1129,"avg_price":64,"med_price":25,"listing_count":38,"create_ts":1564674934328}]'}
# https://api.seatgeek.com/2/events?format=json&per_page=1&performers.slug=Blueface&client_id=MTM4MTIyMDZ8MTU1NDQ3MTkxMy43Ng
# {'CucoThe ComplexSalt Lake CityUT2019-09-19T01:00:00': '[{"Event_ID":"TEST","artist":"Cuco","artist_id":"2Tglaf8nvDzwSQnpSrjLHP","name":"Cuco","ID":4942018,"venue":"The Complex","city":"Salt Lake City","state":"UT","date_UTC":"2019-09-19T01:00:00","lowest_price":53,"highest_price":1185,"avg_price":222,"med_price":79,"listing_count":22,"create_ts":1564674934328}]', 'MatisyahuLegend ValleyThornvilleOH2019-08-01T16:00:00': '[{"Event_ID":"TEST","artist":"Matisyahu","artist_id":"5eyMzR1hYiEZtN2c9ly2kw","name":"The werk out music and arts festival with The Werks, Lettuce, Spafford","ID":4667266,"venue":"Legend Valley","city":"Thornville","state":"OH","date_UTC":"2019-08-01T16:00:00","lowest_price":203,"highest_price":203,"avg_price":203,"med_price":203,"listing_count":1,"create_ts":1564674934328}]', 'RebelutionRockland Trust Bank PavilionBostonMA2019-08-01T23:00:00': '[{"Event_ID":"TEST","artist":"Rebelution","artist_id":"2WjvvwAX0mdWwq3aFuUdtc","name":"Rebelution with Collie Buddz and Protoje","ID":4745382,"venue":"Rockland Trust Bank Pavilion","city":"Boston","state":"MA","date_UTC":"2019-08-01T23:00:00","lowest_price":100,"highest_price":100,"avg_price":100,"med_price":100,"listing_count":1,"create_ts":1564674934328}]', 'dodie9:30 ClubWashingtonDC2019-09-05T23:00:00': '[{"Event_ID":"TEST","artist":"dodie","artist_id":"21TinSsF5ytwsfdyz5VSVS","name":"Dodie Clark with dodie","ID":4702130,"venue":"9:30 Club","city":"Washington","state":"DC","date_UTC":"2019-09-05T23:00:00","lowest_price":18,"highest_price":1129,"avg_price":64,"med_price":25,"listing_count":38,"create_ts":1564674934328}]', 'BluefaceBogartsCincinnatiOH2019-08-02T23:00:00': '[{"Event_ID":"TEST","artist":"Blueface","artist_id":"3Fl1V19tmjt57oBdxXKAjJ","name":"Blueface with NLE Choppa","ID":4917061,"venue":"Bogarts","city":"Cincinnati","state":"OH","date_UTC":"2019-08-02T23:00:00","lowest_price":null,"highest_price":null,"avg_price":null,"med_price":null,"listing_count":null,"create_ts":1564674934328}]'}
# https://api.seatgeek.com/2/events?format=json&per_page=1&performers.slug=for+KING+%26+COUNTRY&client_id=MTM4MTIyMDZ8MTU1NDQ3MTkxMy43Ng
# NO RELATED SEATGEEK EVENTS
# https://api.seatgeek.com/2/events?format=json&per_page=1&performers.slug=Tycho&client_id=MTM4MTIyMDZ8MTU1NDQ3MTkxMy43Ng
# {'CucoThe ComplexSalt Lake CityUT2019-09-19T01:00:00': '[{"Event_ID":"TEST","artist":"Cuco","artist_id":"2Tglaf8nvDzwSQnpSrjLHP","name":"Cuco","ID":4942018,"venue":"The Complex","city":"Salt Lake City","state":"UT","date_UTC":"2019-09-19T01:00:00","lowest_price":53,"highest_price":1185,"avg_price":222,"med_price":79,"listing_count":22,"create_ts":1564674934328}]', 'MatisyahuLegend ValleyThornvilleOH2019-08-01T16:00:00': '[{"Event_ID":"TEST","artist":"Matisyahu","artist_id":"5eyMzR1hYiEZtN2c9ly2kw","name":"The werk out music and arts festival with The Werks, Lettuce, Spafford","ID":4667266,"venue":"Legend Valley","city":"Thornville","state":"OH","date_UTC":"2019-08-01T16:00:00","lowest_price":203,"highest_price":203,"avg_price":203,"med_price":203,"listing_count":1,"create_ts":1564674934328}]', 'RebelutionRockland Trust Bank PavilionBostonMA2019-08-01T23:00:00': '[{"Event_ID":"TEST","artist":"Rebelution","artist_id":"2WjvvwAX0mdWwq3aFuUdtc","name":"Rebelution with Collie Buddz and Protoje","ID":4745382,"venue":"Rockland Trust Bank Pavilion","city":"Boston","state":"MA","date_UTC":"2019-08-01T23:00:00","lowest_price":100,"highest_price":100,"avg_price":100,"med_price":100,"listing_count":1,"create_ts":1564674934328}]', 'dodie9:30 ClubWashingtonDC2019-09-05T23:00:00': '[{"Event_ID":"TEST","artist":"dodie","artist_id":"21TinSsF5ytwsfdyz5VSVS","name":"Dodie Clark with dodie","ID":4702130,"venue":"9:30 Club","city":"Washington","state":"DC","date_UTC":"2019-09-05T23:00:00","lowest_price":18,"highest_price":1129,"avg_price":64,"med_price":25,"listing_count":38,"create_ts":1564674934328}]', 'BluefaceBogartsCincinnatiOH2019-08-02T23:00:00': '[{"Event_ID":"TEST","artist":"Blueface","artist_id":"3Fl1V19tmjt57oBdxXKAjJ","name":"Blueface with NLE Choppa","ID":4917061,"venue":"Bogarts","city":"Cincinnati","state":"OH","date_UTC":"2019-08-02T23:00:00","lowest_price":null,"highest_price":null,"avg_price":null,"med_price":null,"listing_count":null,"create_ts":1564674934328}]', 'TychoThe Greek TheatreLos AngelesCA2019-09-06T03:00:00': '[{"Event_ID":"TEST","artist":"Tycho","artist_id":"5oOhM2DFWab8XhSdQiITry","name":"Tycho with Chrome Sparks","ID":4866091,"venue":"The Greek Theatre","city":"Los Angeles","state":"CA","date_UTC":"2019-09-06T03:00:00","lowest_price":64,"highest_price":673,"avg_price":163,"med_price":134,"listing_count":85,"create_ts":1564674934328}]'}
# https://api.seatgeek.com/2/events?format=json&per_page=1&performers.slug=Dean+Lewis&client_id=MTM4MTIyMDZ8MTU1NDQ3MTkxMy43Ng
# NO RELATED SEATGEEK EVENTS
# https://api.seatgeek.com/2/events?format=json&per_page=1&performers.slug=The+Raconteurs&client_id=MTM4MTIyMDZ8MTU1NDQ3MTkxMy43Ng
# NO RELATED SEATGEEK EVENTS
# https://api.seatgeek.com/2/events?format=json&per_page=1&performers.slug=Smokey+Robinson&client_id=MTM4MTIyMDZ8MTU1NDQ3MTkxMy43Ng
# NO RELATED SEATGEEK EVENTS
# https://api.seatgeek.com/2/events?format=json&per_page=1&performers.slug=Joe+Bonamassa&client_id=MTM4MTIyMDZ8MTU1NDQ3MTkxMy43Ng
# NO RELATED SEATGEEK EVENTS
# https://api.seatgeek.com/2/events?format=json&per_page=1&performers.slug=Atreyu&client_id=MTM4MTIyMDZ8MTU1NDQ3MTkxMy43Ng
# {'CucoThe ComplexSalt Lake CityUT2019-09-19T01:00:00': '[{"Event_ID":"TEST","artist":"Cuco","artist_id":"2Tglaf8nvDzwSQnpSrjLHP","name":"Cuco","ID":4942018,"venue":"The Complex","city":"Salt Lake City","state":"UT","date_UTC":"2019-09-19T01:00:00","lowest_price":53,"highest_price":1185,"avg_price":222,"med_price":79,"listing_count":22,"create_ts":1564674934328}]', 'MatisyahuLegend ValleyThornvilleOH2019-08-01T16:00:00': '[{"Event_ID":"TEST","artist":"Matisyahu","artist_id":"5eyMzR1hYiEZtN2c9ly2kw","name":"The werk out music and arts festival with The Werks, Lettuce, Spafford","ID":4667266,"venue":"Legend Valley","city":"Thornville","state":"OH","date_UTC":"2019-08-01T16:00:00","lowest_price":203,"highest_price":203,"avg_price":203,"med_price":203,"listing_count":1,"create_ts":1564674934328}]', 'RebelutionRockland Trust Bank PavilionBostonMA2019-08-01T23:00:00': '[{"Event_ID":"TEST","artist":"Rebelution","artist_id":"2WjvvwAX0mdWwq3aFuUdtc","name":"Rebelution with Collie Buddz and Protoje","ID":4745382,"venue":"Rockland Trust Bank Pavilion","city":"Boston","state":"MA","date_UTC":"2019-08-01T23:00:00","lowest_price":100,"highest_price":100,"avg_price":100,"med_price":100,"listing_count":1,"create_ts":1564674934328}]', 'dodie9:30 ClubWashingtonDC2019-09-05T23:00:00': '[{"Event_ID":"TEST","artist":"dodie","artist_id":"21TinSsF5ytwsfdyz5VSVS","name":"Dodie Clark with dodie","ID":4702130,"venue":"9:30 Club","city":"Washington","state":"DC","date_UTC":"2019-09-05T23:00:00","lowest_price":18,"highest_price":1129,"avg_price":64,"med_price":25,"listing_count":38,"create_ts":1564674934328}]', 'BluefaceBogartsCincinnatiOH2019-08-02T23:00:00': '[{"Event_ID":"TEST","artist":"Blueface","artist_id":"3Fl1V19tmjt57oBdxXKAjJ","name":"Blueface with NLE Choppa","ID":4917061,"venue":"Bogarts","city":"Cincinnati","state":"OH","date_UTC":"2019-08-02T23:00:00","lowest_price":null,"highest_price":null,"avg_price":null,"med_price":null,"listing_count":null,"create_ts":1564674934328}]', 'TychoThe Greek TheatreLos AngelesCA2019-09-06T03:00:00': '[{"Event_ID":"TEST","artist":"Tycho","artist_id":"5oOhM2DFWab8XhSdQiITry","name":"Tycho with Chrome Sparks","ID":4866091,"venue":"The Greek Theatre","city":"Los Angeles","state":"CA","date_UTC":"2019-09-06T03:00:00","lowest_price":64,"highest_price":673,"avg_price":163,"med_price":134,"listing_count":85,"create_ts":1564674934328}]', 'AtreyuDowntown Las Vegas Events CenterLas VegasNV2019-10-18T10:30:00': '[{"Event_ID":"TEST","artist":"Atreyu","artist_id":"3LkSiHbjqOHCKCqBfEZOTv","name":"Las Rageous (2 Day Pass) with Bring Me The Horizon, Rob Zombie, The Used, and more","ID":4891340,"venue":"Downtown Las Vegas Events Center","city":"Las Vegas","state":"NV","date_UTC":"2019-10-18T10:30:00","lowest_price":256,"highest_price":256,"avg_price":256,"med_price":256,"listing_count":1,"create_ts":1564674934328}]'}
# https://api.seatgeek.com/2/events?format=json&per_page=1&performers.slug=GoldLink&client_id=MTM4MTIyMDZ8MTU1NDQ3MTkxMy43Ng
# {'CucoThe ComplexSalt Lake CityUT2019-09-19T01:00:00': '[{"Event_ID":"TEST","artist":"Cuco","artist_id":"2Tglaf8nvDzwSQnpSrjLHP","name":"Cuco","ID":4942018,"venue":"The Complex","city":"Salt Lake City","state":"UT","date_UTC":"2019-09-19T01:00:00","lowest_price":53,"highest_price":1185,"avg_price":222,"med_price":79,"listing_count":22,"create_ts":1564674934328}]', 'MatisyahuLegend ValleyThornvilleOH2019-08-01T16:00:00': '[{"Event_ID":"TEST","artist":"Matisyahu","artist_id":"5eyMzR1hYiEZtN2c9ly2kw","name":"The werk out music and arts festival with The Werks, Lettuce, Spafford","ID":4667266,"venue":"Legend Valley","city":"Thornville","state":"OH","date_UTC":"2019-08-01T16:00:00","lowest_price":203,"highest_price":203,"avg_price":203,"med_price":203,"listing_count":1,"create_ts":1564674934328}]', 'RebelutionRockland Trust Bank PavilionBostonMA2019-08-01T23:00:00': '[{"Event_ID":"TEST","artist":"Rebelution","artist_id":"2WjvvwAX0mdWwq3aFuUdtc","name":"Rebelution with Collie Buddz and Protoje","ID":4745382,"venue":"Rockland Trust Bank Pavilion","city":"Boston","state":"MA","date_UTC":"2019-08-01T23:00:00","lowest_price":100,"highest_price":100,"avg_price":100,"med_price":100,"listing_count":1,"create_ts":1564674934328}]', 'dodie9:30 ClubWashingtonDC2019-09-05T23:00:00': '[{"Event_ID":"TEST","artist":"dodie","artist_id":"21TinSsF5ytwsfdyz5VSVS","name":"Dodie Clark with dodie","ID":4702130,"venue":"9:30 Club","city":"Washington","state":"DC","date_UTC":"2019-09-05T23:00:00","lowest_price":18,"highest_price":1129,"avg_price":64,"med_price":25,"listing_count":38,"create_ts":1564674934328}]', 'BluefaceBogartsCincinnatiOH2019-08-02T23:00:00': '[{"Event_ID":"TEST","artist":"Blueface","artist_id":"3Fl1V19tmjt57oBdxXKAjJ","name":"Blueface with NLE Choppa","ID":4917061,"venue":"Bogarts","city":"Cincinnati","state":"OH","date_UTC":"2019-08-02T23:00:00","lowest_price":null,"highest_price":null,"avg_price":null,"med_price":null,"listing_count":null,"create_ts":1564674934328}]', 'TychoThe Greek TheatreLos AngelesCA2019-09-06T03:00:00': '[{"Event_ID":"TEST","artist":"Tycho","artist_id":"5oOhM2DFWab8XhSdQiITry","name":"Tycho with Chrome Sparks","ID":4866091,"venue":"The Greek Theatre","city":"Los Angeles","state":"CA","date_UTC":"2019-09-06T03:00:00","lowest_price":64,"highest_price":673,"avg_price":163,"med_price":134,"listing_count":85,"create_ts":1564674934328}]', 'AtreyuDowntown Las Vegas Events CenterLas VegasNV2019-10-18T10:30:00': '[{"Event_ID":"TEST","artist":"Atreyu","artist_id":"3LkSiHbjqOHCKCqBfEZOTv","name":"Las Rageous (2 Day Pass) with Bring Me The Horizon, Rob Zombie, The Used, and more","ID":4891340,"venue":"Downtown Las Vegas Events Center","city":"Las Vegas","state":"NV","date_UTC":"2019-10-18T10:30:00","lowest_price":256,"highest_price":256,"avg_price":256,"med_price":256,"listing_count":1,"create_ts":1564674934328}]', 'GoldLinkKit Carson ParkTaosNM2019-08-16T20:00:00': '[{"Event_ID":"TEST","artist":"GoldLink","artist_id":"5XenQ7XfcvQdfIbpLEFaKQ","name":"Justin Jay: Justin Martin with George Clinton and Too Many Zooz and Mija and Goldlink","ID":4941743,"venue":"Kit Carson Park","city":"Taos","state":"NM","date_UTC":"2019-08-16T20:00:00","lowest_price":null,"highest_price":null,"avg_price":null,"med_price":null,"listing_count":null,"create_ts":1564674934328}]'}
#   Event_ID      artist               artist_id  \
# 0     TEST        Cuco  2Tglaf8nvDzwSQnpSrjLHP
# 0     TEST   Matisyahu  5eyMzR1hYiEZtN2c9ly2kw
# 0     TEST  Rebelution  2WjvvwAX0mdWwq3aFuUdtc
# 0     TEST       dodie  21TinSsF5ytwsfdyz5VSVS
# 0     TEST    Blueface  3Fl1V19tmjt57oBdxXKAjJ
# 0     TEST       Tycho  5oOhM2DFWab8XhSdQiITry
# 0     TEST      Atreyu  3LkSiHbjqOHCKCqBfEZOTv
# 0     TEST    GoldLink  5XenQ7XfcvQdfIbpLEFaKQ
#
#                                                 name       ID  \
# 0                                               Cuco  4942018
# 0  The werk out music and arts festival with The ...  4667266
# 0           Rebelution with Collie Buddz and Protoje  4745382
# 0                             Dodie Clark with dodie  4702130
# 0                           Blueface with NLE Choppa  4917061
# 0                           Tycho with Chrome Sparks  4866091
# 0  Las Rageous (2 Day Pass) with Bring Me The Hor...  4891340
# 0  Justin Jay: Justin Martin with George Clinton ...  4941743
#
#                               venue            city state  \
# 0                       The Complex  Salt Lake City    UT
# 0                     Legend Valley      Thornville    OH
# 0      Rockland Trust Bank Pavilion          Boston    MA
# 0                         9:30 Club      Washington    DC
# 0                           Bogarts      Cincinnati    OH
# 0                 The Greek Theatre     Los Angeles    CA
# 0  Downtown Las Vegas Events Center       Las Vegas    NV
# 0                   Kit Carson Park            Taos    NM
#
#               date_UTC lowest_price highest_price avg_price med_price  \
# 0  2019-09-19T01:00:00           53          1185       222        79
# 0  2019-08-01T16:00:00          203           203       203       203
# 0  2019-08-01T23:00:00          100           100       100       100
# 0  2019-09-05T23:00:00           18          1129        64        25
# 0  2019-08-02T23:00:00         None          None      None      None
# 0  2019-09-06T03:00:00           64           673       163       134
# 0  2019-10-18T10:30:00          256           256       256       256
# 0  2019-08-16T20:00:00         None          None      None      None
#
#   listing_count                  create_ts
# 0            22 2019-08-01 15:55:34.328880
# 0             1 2019-08-01 15:55:34.328880
# 0             1 2019-08-01 15:55:34.328880
# 0            38 2019-08-01 15:55:34.328880
# 0          None 2019-08-01 15:55:34.328880
# 0            85 2019-08-01 15:55:34.328880
# 0             1 2019-08-01 15:55:34.328880
# 0          None 2019-08-01 15:55:34.328880
